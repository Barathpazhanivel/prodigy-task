# %%
DATA SCIENCE TASK 1

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r'C:\Users\avinash\OneDrive\Documents\avinash\PRODIGY_DS_01-Intern-Pinaki-Jupyter-Lab-TASK-01-main\Pinaki_WorldBank_Population\API_SP.POP.TOTL_DS2_en_csv_v2_5871594.csv')

# %%
df
# Out:
#                     Country Name Country Code     Indicator Name  \
# 0                          Aruba          ABW  Population, total
# 1    Africa Eastern and Southern          AFE  Population, total
# 2                    Afghanistan          AFG  Population, total
# 3     Africa Western and Central          AFW  Population, total
# 4                         Angola          AGO  Population, total
# ..                           ...          ...                ...
# 261                       Kosovo          XKX  Population, total
# 262                  Yemen, Rep.          YEM  Population, total
# 263                 South Africa          ZAF  Population, total
# 264                       Zambia          ZMB  Population, total
# 265                     Zimbabwe          ZWE  Population, total
#
#     Indicator Code         1960         1961         1962         1963  \
# 0      SP.POP.TOTL      54608.0      55811.0      56682.0      57475.0
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
ages = np.random.normal(loc=30, scale=10, size=1000)  


genders = ['Male', 'Female', 'Non-Binary']
gender_counts = [450, 520, 30]

plt.figure(figsize=(8, 6))
plt.bar(genders, gender_counts, color='skyblue')
plt.title('Distribution of Genders')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.show()


plt.figure(figsize=(8, 6))
sns.histplot(ages, kde=True, color='salmon')
plt.title('Distribution of Ages')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()
